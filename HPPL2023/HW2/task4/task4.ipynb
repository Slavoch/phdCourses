# %%
# !pip install cupy
# Out:
# ...
#   Using cached cupy-12.2.0.tar.gz (2.0 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [61 lines of output]
#       Clearing directory: /tmp/pip-install-66ea4jj2/cupy_6eabe6fe111c476894fc65a07c721595/cupy/.data
#
#       -------- Configuring Module: cuda --------
#       /usr/bin/ld: cannot find -lcuda: No such file or directory
#       collect2: error: ld returned 1 exit status
#       Cannot build a stub file.
#       Original error: command '/usr/bin/x86_64-linux-gnu-g++' failed with exit code 1
#
#       ************************************************************
#       * CuPy Configuration Summary                               *
#       ************************************************************
#
# ...
